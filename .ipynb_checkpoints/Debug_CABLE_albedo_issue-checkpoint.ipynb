# %%
import os
import netCDF4 as nc
import numpy as np
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from scipy.interpolate import griddata
import matplotlib.ticker as mticker

# %%
# To use PLUMBER2_GPP_common_utils, change directory to where it exists
os.chdir('/g/data/w97/mm3972/scripts/Land_Drought_Rainfall')
from common_utils import *

# %%
restart_file      = '/g/data/w97/mm3972/model/cable/runs/Land_drought_rainfall_runs/spinup_run_1970_1999/restarts/restart_1970.nc'
output_file       = '/g/data/w97/mm3972/model/cable/runs/Land_drought_rainfall_runs/spinup_run_1970_1999/outputs/cable_out_1970.nc'
landsea_file      = '/g/data/w97/mm3972/scripts/Land_Drought_Rainfall/process_for_CABLE/nc_files/gridinfo_AWAP_OpenLandMap_ELEV_DLCM_mask_small_test_domain.nc'
gridinfo_file     = '/g/data/w97/mm3972/scripts/Land_Drought_Rainfall/process_for_CABLE/nc_files/gridinfo_AWAP_OpenLandMap_ELEV_DLCM_fix_MODIS_LAI_albedo_lc_clim_common.nc'
# gridinfo_old_file ="/g/data/w97/mm3972/model/cable/src/CABLE-AUX/offline/mmy_gridinfo_AU/gridinfo_AWAP_OpenLandMap_ELEV_DLCM.nc"

# %%
f_rst       = nc.Dataset(restart_file, 'r')
albedo_rst  = f_rst.variables['albedo'][:].data # 
albsoil_rst = f_rst.variables['albsoil'][:].data # 
albsoilsn_rst = f_rst.variables['albsoilsn'][:].data # 
lat_rst     = f_rst.variables['latitude'][:].data
lon_rst     = f_rst.variables['longitude'][:].data

# %%
f_grid      = nc.Dataset(gridinfo_file, 'r')
albedo_grid = f_grid.variables['Albedo'][:]
lat_grid    = f_grid.variables['latitude'][:]
lon_grid    = f_grid.variables['longitude'][:]
LAI_grid    = f_grid.variables['LAI'][:]

# %%
f_output    = nc.Dataset(output_file, 'r')
albedo_out  = f_output.variables['Albedo'][:]

# %%
f_landsea   = nc.Dataset(landsea_file, 'r')
landsea     = f_landsea.variables['landsea'][:]

# %% [markdown]
# ## Check restart

# %%
lon_grid_2D, lat_grid_2D = np.meshgrid(lon_grid,lat_grid)

# %%
test_rad   = 0 # 0: vis, 1: nir
albedo_tmp = griddata((lon_rst, lat_rst), albedo_rst[test_rad,:], (lon_grid_2D, lat_grid_2D), method='nearest')
var_plot   = np.where((LAI_grid[364,:,:]>0.001) & (landsea ==0), albedo_tmp[:,:], np.nan) # -np.mean(albedo_grid[test_rad:4:2,364,:,:],axis=0)
# albedo_max = np.max(albedo_grid[test_rad:4:2,364,:,:],axis=0)
# albedo_min = np.min(albedo_grid[test_rad:4:2,364,:,:],axis=0)
# var_plot   = np.where((albedo_tmp < albedo_max) & (albedo_tmp > albedo_min), albedo_tmp[:,:]-np.mean(albedo_grid[test_rad:4:2,364,:,:],axis=0), -1)

# plt.contourf(lon_grid, lat_grid, var_plot,cmap='BrBG',levels=[-1.1,-0.001,0.001,1.1])

plt.contourf(lon_grid, lat_grid, var_plot, cmap='BrBG')#,levels=[-1.1,-0.0001,0.0001,1.1])
# plt.contourf(lon_grid, lat_grid, (albedo_tmp > albedo_min),cmap='BrBG',levels=[-1.1,-0.001,0.001,1.1])
plt.colorbar()

# %%
# plt.contourf(lon_grid, lat_grid, var_plot,cmap='BrBG',levels=[-1.1,-0.001,0.001,1.1])
plt.contourf(lon_grid, lat_grid, albedo_tmp,cmap='BrBG',levels=[0,0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,])
plt.colorbar()

# %%
# plt.contourf(lon_grid, lat_grid, var_plot,cmap='BrBG',levels=[-1.1,-0.001,0.001,1.1])
plt.contourf(lon_grid, lat_grid, albedo_min,cmap='BrBG',levels=[0,0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,])
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # plt.contourf(lon_grid, lat_grid, var_plot,cmap='BrBG',levels=[-1.1,-0.001,0.001,1.1])
# ----> 2 plt.contourf(lon_grid, lat_grid, albedo_min,cmap='BrBG',levels=[0,0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,])
#       3 plt.colorbar()
#
# NameError: name 'albedo_min' is not defined

# %%
test_rad   = 1 # 0: vis, 1: nir
albedo_tmp = griddata((lon_rst, lat_rst), albedo_rst[test_rad,:], (lon_grid_2D, lat_grid_2D), method='nearest')
var_plot = np.where(LAI_grid[364,:,:]>0.001, albedo_tmp[:,:]-np.mean(albedo_grid[test_rad:4:2,364,:,:],axis=0), np.nan)
plt.contourf(lon_grid, lat_grid, var_plot,cmap='BrBG')#,levels=[-1,-0.001,0.001,1])
plt.colorbar()

# %% [markdown]
# ## Check output

# %%
# levels = [-1,-0.01,0.01,1]
plt.contourf(lon_grid, lat_grid, albedo_out[300,:,:]-albedo_out[30,:,:],cmap='BrBG')#,levels=levels) np.mean(albedo_grid[0:31,2,:,:],axis=(0))-albedo_out[0,:,:]*2
plt.colorbar()

# %%
plt.contourf(lon_grid, lat_grid, albedo_out[0,:,:]-albedo_grid[1,0,:,:],cmap='BrBG')#,levels=levels)
plt.colorbar()

# plt.contourf(lon_grid, lat_grid, albedo_grid[0,0,:,:] - albedo_grid[1,0,:,:],cmap='BrBG')#,levels=levels)
# plt.colorbar()

# %% [markdown]
# ## plt.contourf(lon_grid, lat_grid, np.where(landsea ==0, albedo_grid[2,364,:,:], np.nan),cmap='BrBG')#,levels=levels)
# plt.colorbar()

# %% [markdown]
# ## Check a small test domain

# %%
file_landsea = "/g/data/w97/mm3972/scripts/Land_Drought_Rainfall/process_for_CABLE/nc_files/gridinfo_AWAP_OpenLandMap_ELEV_DLCM_mask_small_test_domain.nc"
f_landsea    = nc.Dataset(file_landsea, 'r+')
landsea      = f_landsea.variables['landsea'][:].data # 
lat_landsea  = f_landsea.variables['latitude'][:].data
lon_landsea  = f_landsea.variables['longitude'][:].data

lon_landsea_2D, lat_landsea_2D = np.meshgrid(lon_landsea,lat_landsea)
lats         = [-30,-25]
lons         = [149,152]
mask         = (lon_landsea_2D > lons[0]) & (lon_landsea_2D < lons[1]) & (lat_landsea_2D > lats[0]) & (lat_landsea_2D < lats[1])

f_landsea.variables['landsea'][:] = np.where(mask, landsea, 1)
f_landsea.close()

# %% [markdown]
# ### Check gridinfo value at small test domain

# %%
file_landsea = "/g/data/w97/mm3972/scripts/Land_Drought_Rainfall/process_for_CABLE/nc_files/gridinfo_AWAP_OpenLandMap_ELEV_DLCM_mask_small_test_domain.nc"
f_landsea    = nc.Dataset(file_landsea, 'r+')
landsea      = f_landsea.variables['landsea'][:].data # 
lat_landsea  = f_landsea.variables['latitude'][:].data
lon_landsea  = f_landsea.variables['longitude'][:].data

# %%
small_domain_mask = np.where(landsea == 0, True, False)
albedo_small      = np.zeros(365)

for i in np.arange(365):
